# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
f = open('Results/cartpole-reward-history.pickle', 'rb')
reward_history = pickle.load(f)
f.close()

# %%
plt.figure(figsize=(15, 8))
plt.plot(reward_history)
plt.show()
